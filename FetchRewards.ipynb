# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Users Dataframe

# %%
users = pd.read_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/users.csv')
users.head(5)
# Out:
#                    _id/$oid  active  createdDate/$date  lastLogin/$date  \
# 0  5ff1e194b6a9d73a3a9f1052    True      1609687444800     1.609688e+12
# 1  5ff1e194b6a9d73a3a9f1052    True      1609687444800     1.609688e+12
# 2  5ff1e194b6a9d73a3a9f1052    True      1609687444800     1.609688e+12
# 3  5ff1e1eacfcf6c399c274ae6    True      1609687530554     1.609688e+12
# 4  5ff1e194b6a9d73a3a9f1052    True      1609687444800     1.609688e+12
#
#        role signUpSource state
# 0  consumer        Email    WI
# 1  consumer        Email    WI
# 2  consumer        Email    WI
# 3  consumer        Email    WI
# 4  consumer        Email    WI

# %% [markdown]
# #### Dataframe shape

# %%
users.shape
# Out:
# (495, 7)

# %% [markdown]
# #### Column names and changing it to appropriate names

# %%
users.columns
# Out:
# Index(['_id/$oid', 'active', 'createdDate/$date', 'lastLogin/$date', 'role',
#        'signUpSource', 'state'],
#       dtype='object')

# %%
users.columns = ['UsersID', 'Active', 'CreatedDate', 'LastLoginDate', 'Role', 'SignUpSource', 'State']

# %%
users.head()
# Out:
#                     UsersID  Active    CreatedDate  LastLoginDate      Role  \
# 0  5ff1e194b6a9d73a3a9f1052    True  1609687444800   1.609688e+12  consumer
# 1  5ff1e194b6a9d73a3a9f1052    True  1609687444800   1.609688e+12  consumer
# 2  5ff1e194b6a9d73a3a9f1052    True  1609687444800   1.609688e+12  consumer
# 3  5ff1e1eacfcf6c399c274ae6    True  1609687530554   1.609688e+12  consumer
# 4  5ff1e194b6a9d73a3a9f1052    True  1609687444800   1.609688e+12  consumer
#
#   SignUpSource State
# 0        Email    WI
# 1        Email    WI
# 2        Email    WI
# 3        Email    WI
# 4        Email    WI

# %% [markdown]
# #### Checking datatypes of Users dataframe

# %%
users.dtypes
# Out:
# UsersID           object
# Active              bool
# CreatedDate        int64
# LastLoginDate    float64
# Role              object
# SignUpSource      object
# State             object
# dtype: object

# %% [markdown]
# #### Checking null/missing values

# %%
users.isna().sum()
# Out:
# UsersID           0
# Active            0
# CreatedDate       0
# LastLoginDate    62
# Role              0
# SignUpSource     48
# State            56
# dtype: int64

# %%
users.isna().sum().sum()
# Out:
# 166

# %%
users["State"].value_counts()
# Out:
# WI    396
# NH     20
# AL     12
# OH      5
# IL      3
# KY      1
# CO      1
# SC      1
# Name: State, dtype: int64

# %%
users["SignUpSource"].value_counts()
# Out:
# Email     443
# Google      4
# Name: SignUpSource, dtype: int64

# %%
users['State'].fillna('WI', inplace=True)
users['SignUpSource'].fillna('Email', inplace=True)

# %%
for i in users.index:
    if ((pd.isna(users['LastLoginDate'][i])) == True):
        users['LastLoginDate'][i] = users['CreatedDate'][i]
# Out:
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
users.isna().sum()
# Out:
# UsersID          0
# Active           0
# CreatedDate      0
# LastLoginDate    0
# Role             0
# SignUpSource     0
# State            0
# dtype: int64

# %%
users.to_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/users2.csv')

# %% [markdown]
# #### Changing format to Date/Time

# %%
users2 = pd.read_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/users2.csv', index_col=False)
users2.head(5)
# Out:
#                     UsersID  Active    CreatedDate  LastLoginDate      Role  \
# 0  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1609687537858  consumer
# 1  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1609687537858  consumer
# 2  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1609687537858  consumer
# 3  5ff1e1eacfcf6c399c274ae6    True  1609687530554  1609687530597  consumer
# 4  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1609687537858  consumer
#
#   SignUpSource State
# 0        Email    WI
# 1        Email    WI
# 2        Email    WI
# 3        Email    WI
# 4        Email    WI

# %%
import datetime
from datetime import datetime
for i in users2.index:
    users2['CreatedDate'][i] = str(users['CreatedDate'][i])[:10]
    users2['LastLoginDate'][i] = str(users['LastLoginDate'][i])[:10]
    users2['CreatedDate'][i] = datetime.fromtimestamp(int(users2['CreatedDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
    users2['LastLoginDate'][i] = datetime.fromtimestamp(int(users2['LastLoginDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
# Out:
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
users2.head()
# Out:
#                     UsersID  Active             CreatedDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30 AM
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
#
#             LastLoginDate      Role SignUpSource State
# 0  2021-01-03 10:25:37 AM  consumer        Email    WI
# 1  2021-01-03 10:25:37 AM  consumer        Email    WI
# 2  2021-01-03 10:25:37 AM  consumer        Email    WI
# 3  2021-01-03 10:25:30 AM  consumer        Email    WI
# 4  2021-01-03 10:25:37 AM  consumer        Email    WI

# %% [markdown]
# ### Checking duplicate rows

# %%
duplicate = users2[users2.duplicated()]
duplicate
# Out:
#                       UsersID  Active             CreatedDate  \
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 2    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 4    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 5    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 8    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# ..                        ...     ...                     ...
# 490  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
# 491  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
# 492  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
# 493  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
# 494  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
#
#               LastLoginDate         Role SignUpSource State
# 1    2021-01-03 10:25:37 AM     consumer        Email    WI
# 2    2021-01-03 10:25:37 AM     consumer        Email    WI
# ...

# %% [markdown]
# #### Checking the duplicates on the basis of UserID, CreatedDate and LastLoginDate

# %%
duplicated = users2[users2.duplicated(['UsersID', 'CreatedDate', 'LastLoginDate'])]
duplicated.head()
# Out:
#                     UsersID  Active             CreatedDate  \
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 5  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 8  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
#
#             LastLoginDate      Role SignUpSource State
# 1  2021-01-03 10:25:37 AM  consumer        Email    WI
# 2  2021-01-03 10:25:37 AM  consumer        Email    WI
# 4  2021-01-03 10:25:37 AM  consumer        Email    WI
# 5  2021-01-03 10:25:37 AM  consumer        Email    WI
# 8  2021-01-03 10:25:37 AM  consumer        Email    WI

# %%
duplicated.drop_duplicates() #Removing the duplicated rows to keep data integrity
# Out:
#                       UsersID  Active             CreatedDate  \
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04 AM
# 11   5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30 AM
# 24   5ff370c562fde912123a5e0e    True  2021-01-04 02:47:17 PM
# 26   5ff36d0362fde912123a5535    True  2021-01-04 02:31:15 PM
# 27   5ff36be7135e7011bcb856d3    True  2021-01-04 02:26:31 PM
# ..                        ...     ...                     ...
# 429  5fb0a078be5fc9775c1f3945    True  2020-11-14 10:28:56 PM
# 433  5fbc35711d967d1222cbfefc    True  2020-11-23 05:19:29 PM
# 436  5fc961c3b8cfca11a077dd33    True  2020-12-03 05:08:03 PM
# 457  5fa41775898c7a11a6bcef3e    True  2020-11-05 10:17:09 AM
# 476  54943462e4b07e684157a532    True  2014-12-19 09:21:22 AM
#
#               LastLoginDate         Role SignUpSource State
# 1    2021-01-03 10:25:37 AM     consumer        Email    WI
# 11   2021-01-03 10:25:30 AM     consumer        Email    WI
# ...

# %% [markdown]
# ### Brands Dataframe

# %%
brands = pd.read_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/brands.csv')
brands.head(5)
# Out:
#                    _id/$oid       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                cpg/$id/$oid cpg/$ref                       name topBrand  \
# 0  601ac114be37ce2ead437550     Cogs  test brand @1612366101024    False
# 1  5332f5fbe4b03c9a25efd0ba     Cogs                  Starbucks    False
# 2  601ac142be37ce2ead437559     Cogs  test brand @1612366146176    False
# 3  601ac142be37ce2ead437559     Cogs  test brand @1612366146051    False
# 4  5332fa12e4b03c9a25efd1e7     Cogs  test brand @1612366146827    False
#
#                        brandCode
# 0                            NaN
# ...

# %% [markdown]
# #### Dataframe shape

# %%
brands.shape
# Out:
# (1167, 9)

# %% [markdown]
# #### Column names and changing it to appropriate names

# %%
brands.columns
# Out:
# Index(['_id/$oid', 'barcode', 'category', 'categoryCode', 'cpg/$id/$oid',
#        'cpg/$ref', 'name', 'topBrand', 'brandCode'],
#       dtype='object')

# %%
brands.columns = ['BrandID', 'Barcode','Category','CategoryCode','CPGID','CPGRef','BrandName','topBrand','brandCode']

# %%
brands.head()
# Out:
#                     BrandID       Barcode        Category      CategoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                       CPGID CPGRef                  BrandName topBrand  \
# 0  601ac114be37ce2ead437550   Cogs  test brand @1612366101024    False
# 1  5332f5fbe4b03c9a25efd0ba   Cogs                  Starbucks    False
# 2  601ac142be37ce2ead437559   Cogs  test brand @1612366146176    False
# 3  601ac142be37ce2ead437559   Cogs  test brand @1612366146051    False
# 4  5332fa12e4b03c9a25efd1e7   Cogs  test brand @1612366146827    False
#
#                        brandCode
# 0                            NaN
# ...

# %% [markdown]
# #### Dataframe Datatypes

# %%
brands.dtypes
# Out:
# BrandID         object
# Barcode          int64
# Category        object
# CategoryCode    object
# CPGID           object
# CPGRef          object
# BrandName       object
# topBrand        object
# brandCode       object
# dtype: object

# %% [markdown]
# #### Checking null/missing values

# %%
brands.isna().sum()
# Out:
# BrandID           0
# Barcode           0
# Category        155
# CategoryCode    650
# CPGID             0
# CPGRef            0
# BrandName         0
# topBrand        612
# brandCode       269
# dtype: int64

# %%
brands.isna().sum().sum()
# Out:
# 1686

# %%
brands['Category'].fillna('Other', inplace=True)

# %%
for i in brands.index:
    if ((pd.isna(brands['CategoryCode'][i])) == True):
        brands['CategoryCode'][i] = str(brands['Category'][i]).upper()
    if ((pd.isna(brands['brandCode'][i])) == True):
        brands['brandCode'][i] = str(brands['BrandName'][i]).upper()
# Out:
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
brands['topBrand'].fillna('Not known', inplace=True)

# %%
brands.isna().sum()
# Out:
# BrandID         0
# Barcode         0
# Category        0
# CategoryCode    0
# CPGID           0
# CPGRef          0
# BrandName       0
# topBrand        0
# brandCode       0
# dtype: int64

# %% [markdown]
# #### Checking duplicate rows

# %%
duplicate1 = brands[brands.duplicated()]
duplicate1
# Out:
# Empty DataFrame
# Columns: [BrandID, Barcode, Category, CategoryCode, CPGID, CPGRef, BrandName, topBrand, brandCode]
# Index: []

# %% [markdown]
# ### Receipts Dataframe

# %%
receipts = pd.read_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/receipts.csv')
receipts.head(5)
# Out:
#                              _id  bonusPointsEarned  \
# 0  $oid:5ff1e1eb0a720f0523000575              500.0
# 1  $oid:5ff1e1bb0a720f052300056b              150.0
# 2  $oid:5ff1e1f10a720f052300057a                5.0
# 3  $oid:5ff1e1ee0a7214ada100056f                5.0
# 4  $oid:5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason           createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  $date:1609687531000
# 1  Receipt number 5 completed, bonus point schedu...  $date:1609687483000
# 2                         All-receipts receipt bonus  $date:1609687537000
# 3                         All-receipts receipt bonus  $date:1609687534000
# 4                         All-receipts receipt bonus  $date:1609687506000
#
#            dateScanned         finishedDate           modifyDate  \
# 0  $date:1609687531000  $date:1609687531000  $date:1609687536000
# 1  $date:1609687483000  $date:1609687483000  $date:1609687488000
# ...

# %% [markdown]
# #### Dataframe shape

# %%
receipts.shape
# Out:
# (1119, 15)

# %% [markdown]
# #### Column names and changing it to appropriate names

# %%
receipts.columns
# Out:
# Index(['_id', 'bonusPointsEarned', 'bonusPointsEarnedReason', 'createDate',
#        'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate',
#        'pointsEarned', 'purchaseDate', 'purchasedItemCount',
#        'rewardsReceiptItemList', 'rewardsReceiptStatus', 'totalSpent',
#        'userId'],
#       dtype='object')

# %%
receipts.columns = ['ReceiptID', 'BonusPointsEarned', 'BonusPointsEarnedReason', 'CreateDate', 'DateScanned', 'FinishedDate', 'ModifyDate', 'PointsAwardedDate', 'PointsEarned', 'PurchaseDate', 'PurchaseItemCount', 'RewardsReceiptItemList', 'RewardsReceiptStatus', 'TotalSpent', 'UserID']

# %%
receipts.head()
# Out:
#                        ReceiptID  BonusPointsEarned  \
# 0  $oid:5ff1e1eb0a720f0523000575              500.0
# 1  $oid:5ff1e1bb0a720f052300056b              150.0
# 2  $oid:5ff1e1f10a720f052300057a                5.0
# 3  $oid:5ff1e1ee0a7214ada100056f                5.0
# 4  $oid:5ff1e1d20a7214ada1000561                5.0
#
#                              BonusPointsEarnedReason           CreateDate  \
# 0  Receipt number 2 completed, bonus point schedu...  $date:1609687531000
# 1  Receipt number 5 completed, bonus point schedu...  $date:1609687483000
# 2                         All-receipts receipt bonus  $date:1609687537000
# 3                         All-receipts receipt bonus  $date:1609687534000
# 4                         All-receipts receipt bonus  $date:1609687506000
#
#            DateScanned         FinishedDate           ModifyDate  \
# 0  $date:1609687531000  $date:1609687531000  $date:1609687536000
# 1  $date:1609687483000  $date:1609687483000  $date:1609687488000
# ...

# %% [markdown]
# #### Checking datatypes of Receipts dataframe

# %%
receipts.dtypes
# Out:
# ReceiptID                   object
# BonusPointsEarned          float64
# BonusPointsEarnedReason     object
# CreateDate                  object
# DateScanned                 object
# FinishedDate                object
# ModifyDate                  object
# PointsAwardedDate           object
# PointsEarned               float64
# PurchaseDate                object
# PurchaseItemCount          float64
# RewardsReceiptItemList      object
# RewardsReceiptStatus        object
# TotalSpent                 float64
# UserID                      object
# dtype: object

# %% [markdown]
# #### Data cleaning

# %%
receipts['ReceiptID'] = receipts['ReceiptID'].str[5:]
receipts['CreateDate'] = receipts['CreateDate'].str[6:]
receipts['DateScanned'] = receipts['DateScanned'].str[6:]
receipts['FinishedDate'] = receipts['FinishedDate'].str[6:]
receipts['ModifyDate'] = receipts['ModifyDate'].str[6:]
receipts['PointsAwardedDate'] = receipts['PointsAwardedDate'].str[6:]
receipts['PurchaseDate'] = receipts['PurchaseDate'].str[6:]

# %%
receipts2 = receipts['RewardsReceiptItemList']
receipts = receipts.drop('RewardsReceiptItemList', 1)
receipts2.head()
# Out:
# 0    barcode:4011|description:ITEM NOT FOUND|finalP...
# 1    barcode:4011|description:ITEM NOT FOUND|finalP...
# 2    needsFetchReview:false|partnerItemId:1|prevent...
# 3    barcode:4011|description:ITEM NOT FOUND|finalP...
# 4    barcode:4011|description:ITEM NOT FOUND|finalP...
# Name: RewardsReceiptItemList, dtype: object

# %% [markdown]
# #### Checking Null/Missing Values

# %%
receipts.isna().sum()
# Out:
# ReceiptID                    0
# BonusPointsEarned          575
# BonusPointsEarnedReason    575
# CreateDate                   0
# DateScanned                  0
# FinishedDate               551
# ModifyDate                   0
# PointsAwardedDate          582
# PointsEarned               510
# PurchaseDate               448
# PurchaseItemCount          484
# RewardsReceiptStatus        17
# TotalSpent                 452
# UserID                      17
# dtype: int64

# %%
receipts['BonusPointsEarned'].fillna(0 , inplace=True)

# %%
receipts['BonusPointsEarnedReason'].fillna('No Bonus Points Awarded', inplace=True)

# %%
receipts['PointsEarned'].fillna(0 , inplace=True)

# %%
receipts = receipts.drop('FinishedDate', 1)

# %%
receipts['PointsAwardedDate'].fillna(min((receipts['PointsAwardedDate']).astype(str)), inplace=True)

# %%
for i in receipts.index:
    if ((pd.isna(receipts['PurchaseDate'][i])) == True):
        receipts['PurchaseDate'][i] = receipts['CreateDate'][i]
# Out:
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
receipts['RewardsReceiptStatus'].fillna('Not Known', inplace=True)

# %%
receipts['PurchaseItemCount'].fillna(0 , inplace=True)

# %%
receipts['TotalSpent'].fillna(0 , inplace=True)

# %%
receipts.dropna()
# Out:
#                      ReceiptID  BonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575              500.0
# 1     5ff1e1bb0a720f052300056b              150.0
# 2     5ff1e1f10a720f052300057a                5.0
# 3     5ff1e1ee0a7214ada100056f                5.0
# 4     5ff1e1d20a7214ada1000561                5.0
# ...                        ...                ...
# 1114  603cc0630a720fde100003e6               25.0
# 1115  603d0b710a720fde1000042a                0.0
# 1116  603cf5290a720fde10000413                0.0
# 1117  603ce7100a7217c72c000405               25.0
# 1118  603c4fea0a7217c72c000389                0.0
#
#                                 BonusPointsEarnedReason     CreateDate  \
# 0     Receipt number 2 completed, bonus point schedu...  1609687531000
# 1     Receipt number 5 completed, bonus point schedu...  1609687483000
# 2                            All-receipts receipt bonus  1609687537000
# 3                            All-receipts receipt bonus  1609687534000
# ...

# %%
receipts.isna().sum()
# Out:
# ReceiptID                   0
# BonusPointsEarned           0
# BonusPointsEarnedReason     0
# CreateDate                  0
# DateScanned                 0
# ModifyDate                  0
# PointsAwardedDate           0
# PointsEarned                0
# PurchaseDate                0
# PurchaseItemCount           0
# RewardsReceiptStatus        0
# TotalSpent                  0
# UserID                     17
# dtype: int64

# %%
receipts.head()
# Out:
#                   ReceiptID  BonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              BonusPointsEarnedReason     CreateDate  \
# 0  Receipt number 2 completed, bonus point schedu...  1609687531000
# 1  Receipt number 5 completed, bonus point schedu...  1609687483000
# 2                         All-receipts receipt bonus  1609687537000
# 3                         All-receipts receipt bonus  1609687534000
# 4                         All-receipts receipt bonus  1609687506000
#
#      DateScanned     ModifyDate PointsAwardedDate  PointsEarned  \
# 0  1609687531000  1609687536000     1609687531000         500.0
# 1  1609687483000  1609687488000     1609687483000         150.0
# 2  1609687537000  1609687542000     1604089080000           5.0
# ...

# %%
receipts.to_csv('C:/Users/prath/OneDrive/Desktop/FetchRewards/receipts2.csv')

# %% [markdown]
# #### Changing format to Date/Time

# %%
import datetime
from datetime import datetime
for i in receipts.index:
    receipts['CreateDate'][i] = str(receipts['CreateDate'][i])[:10]
    receipts['DateScanned'][i] = str(receipts['DateScanned'][i])[:10]
    receipts['ModifyDate'][i] = str(receipts['ModifyDate'][i])[:10]
    receipts['PointsAwardedDate'][i] = str(receipts['PointsAwardedDate'][i])[:10]
    receipts['PurchaseDate'][i] = str(receipts['PurchaseDate'][i])[:10]
    receipts['CreateDate'][i] = datetime.fromtimestamp(int(receipts['CreateDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
    receipts['DateScanned'][i] = datetime.fromtimestamp(int(receipts['DateScanned'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
    receipts['ModifyDate'][i] = datetime.fromtimestamp(int(receipts['ModifyDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
    receipts['PointsAwardedDate'][i] = datetime.fromtimestamp(int(receipts['PointsAwardedDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
    receipts['PurchaseDate'][i] = datetime.fromtimestamp(int(receipts['PurchaseDate'][i])).strftime('%Y-%m-%d %I:%M:%S %p')
# Out:
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\prath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
receipts.head()
# Out:
#                   ReceiptID  BonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              BonusPointsEarnedReason              CreateDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 10:25:31 AM
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 10:24:43 AM
# 2                         All-receipts receipt bonus  2021-01-03 10:25:37 AM
# 3                         All-receipts receipt bonus  2021-01-03 10:25:34 AM
# 4                         All-receipts receipt bonus  2021-01-03 10:25:06 AM
#
#               DateScanned              ModifyDate       PointsAwardedDate  \
# 0  2021-01-03 10:25:31 AM  2021-01-03 10:25:36 AM  2021-01-03 10:25:31 AM
# ...

# %% [markdown]
# #### rewardsReceiptItemList

# %%
type(receipts2)
# Out:
# pandas.core.series.Series

# %%
rec = receipts2.str.split("\n", expand = True)

# %%
rec.fillna(" ", inplace = True)

# %%
rec.head()
# Out:
#                                                  0    \
# 0  barcode:4011|description:ITEM NOT FOUND|finalP...
# 1  barcode:4011|description:ITEM NOT FOUND|finalP...
# 2  needsFetchReview:false|partnerItemId:1|prevent...
# 3  barcode:4011|description:ITEM NOT FOUND|finalP...
# 4  barcode:4011|description:ITEM NOT FOUND|finalP...
#
#                                                  1   2   3   4   5   6   7    \
# 0
# 1  barcode:028400642255|description:DORITOS TORTI...
# 2
# 3
# 4  barcode:1234|finalPrice:2.56|itemPrice:2.56|ne...
#
#   8   9    ... 168 169 170 171 172 173 174 175 176 177
# 0          ...
# 1          ...
# 2          ...
# 3          ...
# 4          ...
#
# [5 rows x 178 columns]

# %%
col_names = ['barcode', 'needsFetchReview', 'brandCode', 'description', 'discountedItemPrice', 'needsFetchReviewReason', 'partnerItemId', 'competitiveProduct', 'finalPrice', 'competitorRewardsGroup', 'preventTargetGapPoints', 'itemPrice', 'userFlaggedQuantity', 'userFlaggedBarcode', 'originalReceiptItemText', 'userFlaggedNewItem', 'userFlaggedPrice', 'priceAfterCoupon', 'pointsEarned', 'quantityPurchased', 'userFlaggedDescription','metabriteCampaignId','originalReceiptItemText','metabriteBarcode','metabriteDescription','pointsPayerId', 'quantity', 'targetPrice']
col_names_dict = {i:[] for i in col_names}

# %%
lst = []
for i in rec.columns:
    for j in rec[i]:
        for cn in col_names_dict:
            if cn in j:
                col_names_dict[cn].append(j.split(cn)[-1].split('|')[0].split(':')[-1])
            else:
                col_names_dict[cn].append('')
    #lst.append(rec[i].str.split("|", expand = True))

# %%
[len(v) for k,v in col_names_dict.items()]
# Out:
# [199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182,
#  199182]

# %%
df_test = pd.DataFrame(col_names_dict)

# %%
df_test.head()
# Out:
#   barcode needsFetchReview brandCode     description discountedItemPrice  \
# 0    4011            false            ITEM NOT FOUND
# 1    4011                             ITEM NOT FOUND
# 2                    false
# 3    4011            false            ITEM NOT FOUND
# 4    4011                             ITEM NOT FOUND
#
#   needsFetchReviewReason partnerItemId competitiveProduct finalPrice  \
# 0                                    1                         26.00
# 1                                    1                             1
# 2                                    1
# 3                                    1                         28.00
# 4                                    1                             1
#
#   competitorRewardsGroup  ... priceAfterCoupon pointsEarned quantityPurchased  \
# 0                         ...                                               5
# 1                         ...                                               1
# ...

# %%
rewardsrewardsReceiptItemList = df_test

# %% [markdown]
# #### Final rewardsrewardsReceiptItemList after data preprocessing techniques

# %%
rewardsrewardsReceiptItemList.head()
# Out:
#   barcode needsFetchReview brandCode     description discountedItemPrice  \
# 0    4011            false            ITEM NOT FOUND
# 1    4011                             ITEM NOT FOUND
# 2                    false
# 3    4011            false            ITEM NOT FOUND
# 4    4011                             ITEM NOT FOUND
#
#   needsFetchReviewReason partnerItemId competitiveProduct finalPrice  \
# 0                                    1                         26.00
# 1                                    1                             1
# 2                                    1
# 3                                    1                         28.00
# 4                                    1                             1
#
#   competitorRewardsGroup  ... priceAfterCoupon pointsEarned quantityPurchased  \
# 0                         ...                                               5
# 1                         ...                                               1
# ...
